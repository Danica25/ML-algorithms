# %% [markdown]
# *Dimensionality_reduction*
# danica j

# %% [markdown]
# **STEPS:**
# (i)    Import the necessary libraries.
#
#    (ii)   Read the mushrooms.csv file.
#
#    (iii)  Encode the string characters into ints.
#
#    (iv)   Apply the transformation to all the columns.
#
#    (v)    Scale the features with the standard scaler.
#
#    (vi)   Use PCA to get the list of features and plot which features have the most explanatory power, or have the most variance.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-cacad90d-bfa5-462e-9aa1-e0afa04429e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cacad90d-bfa5-462e-9aa1-e0afa04429e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mushrooms.csv to mushrooms.csv

# %%
import io
m_data = pd.read_csv('mushrooms.csv')

# %%
encoder = LabelEncoder()

# Now apply the transformation to all the columns:
for col in m_data.columns:
    m_data[col] = encoder.fit_transform(m_data[col])

X_features = m_data.iloc[:,1:23]
y_label = m_data.iloc[:, 0]

# %%
X_features
# Out:
#       cap-shape  cap-surface  cap-color  ...  spore-print-color  population  habitat
# 0             5            2          4  ...                  2           3        5
# 1             5            2          9  ...                  3           2        1
# 2             0            2          8  ...                  3           2        3
# 3             5            3          8  ...                  2           3        5
# 4             5            2          3  ...                  3           0        1
# ...         ...          ...        ...  ...                ...         ...      ...
# 8119          3            2          4  ...                  0           1        2
# 8120          5            2          4  ...                  0           4        2
# 8121          2            2          4  ...                  0           1        2
# 8122          3            3          4  ...                  7           4        2
# ...

# %%
y_label
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
X_features.shape
# Out:
# (8124, 22)

# %%
y_label.shape
# Out:
# (8124,)

# %%
# Scale the features
scaler = StandardScaler()
X_features = scaler.fit_transform(X_features)

# %%
X_features
# Out:
# array([[ 1.02971224,  0.14012794, -0.19824983, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.02971224,  0.14012794,  1.76587407, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [-2.08704716,  0.14012794,  1.37304929, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [-0.8403434 ,  0.14012794, -0.19824983, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [-0.21699152,  0.95327039, -0.19824983, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.02971224,  0.14012794, -0.19824983, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
# Visualize
pca = PCA()
X_transform= pca.fit_transform(X_features)
pca_variance = pca.explained_variance_

# %%
X_transform.shape
# Out:
# (8124, 22)

# %%
plt.figure(figsize=(8, 6))
plt.bar(range(22), pca_variance, alpha=0.5, align='center', label='individual variance')
plt.legend()
plt.ylabel('Variance ratio')
plt.xlabel('Principal components')
plt.show()

# %%
pca2 = PCA(n_components=17)
pca2.fit(X_features)
x_3d = pca2.transform(X_features)

# %%
x_3d.shape
# Out:
# (8124, 17)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_3d[:,0], x_3d[:,16], c=m_data['class'])
plt.show()

# %%
pca3 = PCA(n_components=2)
pca3.fit(X_features)
x_3d = pca3.transform(X_features)

# %%
x_3d.shape
# Out:
# (8124, 2)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x_3d[:,0], x_3d[:,1], c=m_data['class'])
plt.show()
